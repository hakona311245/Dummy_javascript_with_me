# %% [markdown]
# # Interaction: alert, confirm, prompt

# %% [markdown]
# So alert is just a message:

# %%
alert("Hello");

# %% [markdown]
# prompt is asking for an input

# %% [markdown]
# result = prompt(title, [default]);

# %% [markdown]
# u can either call out the variable first like let result or you can straight up use it as it is

# %% [markdown]
# confirm is just like above but for yes/no operation

# %%
result = confirm(question);

# %% [markdown]
# the variable will automically know that it is a bool var
