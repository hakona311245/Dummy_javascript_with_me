# %% [markdown]
# ## So basically there is difference time mark between old js and newer one

# %% [markdown]
# And to avoid it run wrong or just error, we have "use strict"

# %%
"use strictt";  
alert( "I'm JavaScript!" );
