# %% [markdown]
# To start:

# %% [markdown]
# If you want to put the script directly into the web page:

# %%
<!DOCTYPE html>
<html>

<body>

  <script>
    alert( "I'm JavaScript!" );
  </script>

</body>

</html>

# %% [markdown]
# You can also link to an external script file:

# %%
<!DOCTYPE html>
<html>

<body>

  <script>
    alert( "I'm JavaScript!" );
  </script>

</body>

</html>
